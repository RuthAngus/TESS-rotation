# %% [markdown]
# # Let's measure some rotation periods of CVZ stars!

# %%
# %matplotlib inline

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import lightcurvestuff as lcs
import starspot as ss
from tqdm import trange
import starspot.rotation_tools as rt

# %% [markdown]
# Load the catalogs.

# %%
fn = glob.glob("/Users/rangus/projects/TESSlightcurves/*fits")
# ticid = extract_ticid(fn[5])  # 2

# %%
import re

def extract_ticid(fn):
    return int(re.findall(r'\d+', fn)[2])

# %%
# Load multiple sector lcs:
df = pd.read_csv("stars_with_10_or_more_sectors.csv")

ticid = df.ticid.values[0]

ticid = 350336553  # 15 or 30 day period
ticid = 350478801
ticid = 260372062
ticid = 150428135
print(ticid)

path = "/Users/rangus/projects/TESSlightcurves/"
path = "/Users/rangus/projects/AAS_hack_2020/"
str_ticid = str(int(ticid)).zfill(16)
tfile = "tess?????????????-s????-{}-????-s_lc.fits".format(str_ticid)
tfile = "*.fits"

ticpath = os.path.join(path, tfile)
fnames = sorted(glob.glob(ticpath))
print(fnames)
time, flux, flux_err = lcs.tools.load_and_split_TESS(fnames, flux_type="PDCSAP_FLUX")
print(len(time), "sectors")

# print(flux[3])
# plt.plot(time[3], flux[3])

# time.pop(3)
# flux.pop(3)
# flux_err.pop(3)
# Out:
# 150428135
# ['/Users/rangus/projects/AAS_hack_2020/tess-s0001-4-3_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0002-4-3_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0003-4-4_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0004-4-4_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0005-4-4_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0006-4-1_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0007-4-1_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0008-4-1_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0009-4-2_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0010-4-2_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0011-4-2_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0012-4-2_97.096787_-65.579312_32x32_astrocut.fits', '/Users/rangus/projects/AAS_hack_2020/tess-s0013-4-3_97.096787_-65.579312_32x32_astrocut.fits']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/astropy/io/fits/column.py in _get_index(names, key)
#    2008         try:
# -> 2009             indx = names.index(key.rstrip())
#    2010         except ValueError:
#
# ValueError: 'PDCSAP_FLUX' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-ae94d0ce8638> in <module>
#      19 fnames = sorted(glob.glob(ticpath))
#      20 print(fnames)
# ---> 21 time, flux, flux_err = lcs.tools.load_and_split_TESS(fnames, flux_type="PDCSAP_FLUX")
#      22 print(len(time), "sectors")
#      23
#
# ~/projects/lightcurvestuff/lightcurvestuff/tools.py in load_and_split_TESS(fnames, flux_type, stitch)
#      53         hdulist = fits.open(fnames[i])
#      54         t = hdulist[1].data
# ---> 55         x, y, yerr = t["TIME"], t["{}".format(flux_type)], \
#      56             t["{}_ERR".format(flux_type)]
#      57         m = np.isfinite(x) * np.isfinite(y) * np.isfinite(yerr) \
#
# /anaconda3/lib/python3.7/site-packages/astropy/io/fits/fitsrec.py in __getitem__(self, key)
#     485
#     486         if isinstance(key, str):
# --> 487             return self.field(key)
#     488
#     489         # Have to view as a recarray then back as a FITS_rec, otherwise the
#
# /anaconda3/lib/python3.7/site-packages/astropy/io/fits/fitsrec.py in field(self, key)
#     675         # NOTE: The *column* index may not be the same as the field index in
#     676         # the recarray, if the column is a phantom column
# --> 677         column = self.columns[key]
#     678         name = column.name
#     679         format = column.format
#
# /anaconda3/lib/python3.7/site-packages/astropy/io/fits/column.py in __getitem__(self, key)
#    1614     def __getitem__(self, key):
#    1615         if isinstance(key, str):
# -> 1616             key = _get_index(self.names, key)
#    1617
#    1618         x = self.columns[key]
#
# /anaconda3/lib/python3.7/site-packages/astropy/io/fits/column.py in _get_index(names, key)
#    2016                 indx = names.index(_key)
#    2017             elif count == 0:
# -> 2018                 raise KeyError("Key '{}' does not exist.".format(key))
#    2019             else:              # multiple match
#    2020                 raise KeyError("Ambiguous key name '{}'.".format(key))
#
# KeyError: "Key 'PDCSAP_FLUX' does not exist."

# %% [markdown]
# Sigma clip each sector.

# %%
def sigma_clip_TESS_sector(x, y, yerr):
    x, y, yerr = np.array(x), np.array(y), np.array(yerr)
    
    # Initial removal of extreme outliers.
    m = rt.sigma_clip(y, nsigma=7)
    x, y, yerr = x[m], y[m], yerr[m]

    # Remove outliers using Sav-Gol filter
    smooth, mask = rt.filter_sigma_clip(x, y)
    resids = y - smooth
    stdev = np.std(resids)
    return x[mask], y[mask], yerr[mask], stdev

x, y, yerr, std = [], [], [], []
for i in trange(len(time)):
    t, f, ferr, stdev = sigma_clip_TESS_sector(time[i], flux[i], flux_err[i])
    x.append(t)
    y.append(f)
    yerr.append(ferr)
    std.append(stdev)
# Out:
# 100%|██████████| 12/12 [00:04<00:00,  2.27it/s]

# %% [markdown]
# Find gap times and step offsets.

# %%
def find_gap_times(time):
    
    start_times, stop_times = [], []
    for i in range(len(time)):
        start_times.append(min(time[i]))
        stop_times.append(max(time[i]))
    
    return start_times[1:]

gap_times = find_gap_times(x)

def find_steps(y):
    # Meds
    meds = []
    for i in range(len(y)):
        meds.append(np.median(y[i]))
    return meds[1:]

original_flux_median = np.median(y[0])
y -= original_flux_median
steps = find_steps(y)

# %% [markdown]
# Format light curves.

# %%
def format_lc(t, y, yerr, subsample=10):
    
    # turn into arrays
    t = np.array([i for j in x for i in j], dtype="float64")
    y = np.array([i for j in y for i in j], dtype="float64")
    yerr = np.array([i for j in yerr for i in j], dtype="float64")

    # Remove NaNs
    m = np.isfinite(t) * np.isfinite(y) * np.isfinite(yerr)
    t, y, yerr = t[m], y[m], yerr[m]

    # Subsample
    t, y, yerr = t[::subsample], y[::subsample], yerr[::subsample]

    # Sort by time
    inds = np.argsort(t)
    t, y, yerr = t[inds], y[inds], yerr[inds]

    return t, y, yerr

t, y, yerr = format_lc(x, y, yerr)

# Start at time 0
gap_times -= t[0]
t -= t[0]

# %%
plt.figure(figsize=(16, 4))
plt.errorbar(t, y, yerr=yerr, fmt="k.", alpha=.5)

from starspot.stitch import step_model

mu = step_model(t, gap_times, steps)
print(steps)
plt.plot(t, mu, "C1", zorder=10)

for g in gap_times:
    plt.axvline(g, color="k", ls="--")
# Out:
# [68544.5, 69774.25, 101359.25, 103086.5, 80681.5, 79625.94, 98583.94, 73493.625, 74814.375, 56829.188, 64104.75]

# %%
# Correct the light curve
best_fit_mu = step_model(t, gap_times, steps)
corrected_y = y - best_fit_mu

plt.figure(figsize=(16, 4))
plt.plot(t, corrected_y, "k.", alpha=.5)
plt.xlim(100, 250)
# Out:
# (100, 250)

# %% [markdown]
# Find the offsets:]

# %%
import starspot.stitch as sps

star = sps.StitchModel(t, y, yerr, gap_times, steps, 2.0)
star.model_offsets()
map_soln = star.find_optimum()
# Out:
# success: False
# initial logp: -2975207777.3286467
# final logp: nan

# %%
best_steps = []
for i in range(1, len(time)-1):
    best_steps.append(map_soln[0]["step{}".format(i+1)])

# %%
# Correct the light curve
best_fit_mu = step_model(t, gap_times, steps)
naive_y = y - best_fit_mu
corrected_y = y - step_model(t, gap_times, best_steps)

test_t = np.linspace(0, max(t), 1000)
mu, var = star.evaluate_model(test_t)
plt.plot(t, y, ".")
plt.plot(test_t, mu)

# %% [markdown]
# Median-normalize light curve.

# %%
corrected_y /= original_flux_median

# %%
rotate = ss.RotationModel(t, corrected_y, yerr)
ls_period = rotate.ls_rotation()

def myround(x, base=5):
    return int(base * round(float(x)/base))

acf_period = rotate.acf_rotation(interval=0.00138889, cutoff=1, window_length=999)
# fig = rotate.big_plot(methods=["acf", "ls"], xlim=(-1, 50));

period_grid = np.linspace(1, 30, 1000)
pdm_period = rotate.pdm_rotation(period_grid)
fig = rotate.big_plot(methods=["pdm", "ls", "acf"], xlim=(0, max(t)));

print("log10(Rvar) = ", np.log10(rotate.Rvar*1e6), "ppm")
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# 100%|██████████| 1000/1000 [00:05<00:00, 169.77it/s]
# log10(Rvar) =  4.454158693957085 ppm

# %%
# fig = plt.figure(figsize=(16, 12), dpi=200)

# ax1 = fig.add_subplot(311)
# ax1.plot(x, y+1, "k.", alpha=.1, rasterized=True)
# ax1.set_ylabel("Normalized Flux")
# ax1.set_xlim(0, max(x))

# ax2 = fig.add_subplot(312)
# ax2.plot(x, y+1, "k.", alpha=.1, rasterized=True)
# ax2.set_xlim(0, 100)
# ax2.set_ylabel("Normalized Flux")

# ax3 = fig.add_subplot(313)
# ax3.plot(x, y+1, "k.", alpha=.1, rasterized=True)
# ax3.set_xlim(0, 30)
# ax3.set_xlabel("Time [days]")
# ax3.set_ylabel("Normalized Flux");

# %% [markdown]
# Don't calculate ACF because there are so many missing sectors, it won't work very well. Instead, calculate ACF for every sector individually.

# %%
x, y, yerr = lcs.tools.load_and_split_TESS(fnames)

# %%
from tqdm import trange
acfs, lags = [], []
for i in trange(len(x)):
    star = ss.RotationModel(x[i], y[i], yerr[i])
    acf_period = star.acf_rotation(interval="TESS", smooth=9, cutoff=1.2)
    acfs.append(star.acf)
    lags.append(star.lags)
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 64.38it/s]

# %%
from scipy.signal import savgol_filter
from starspot.rotation_tools import get_peak_statistics

# %%
fig = plt.figure(figsize=(16, 9), dpi=200)
xp = np.linspace(0, 14, 1000)
smooth_tot, peaks = np.zeros_like(xp), []
for i in trange(len(acfs)):
    smooth = savgol_filter(acfs[i], 1001, 3)
    xpeak, ypeak = get_peak_statistics(lags[i], smooth)
    peaks.append(xpeak[0])
    plt.axvline(xpeak[0], alpha=.5)
    plt.plot(lags[i], smooth, "C0", alpha=.3)
    y = np.interp(xp, lags[i], smooth)
    smooth_tot += y
plt.xlabel("Time [days]")
plt.ylabel("ACF");
plt.axvline(np.median(peaks), color="k")
print(np.median(peaks))
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 78.46it/s]
# 7.655561680000001

# %%
fig = plt.figure(figsize=(16, 9), dpi=200)
plt.plot(xp, smooth_tot, "C0")
xpeak, ypeak = get_peak_statistics(xp, smooth_tot)
plt.axvline(xpeak[0])
plt.xlabel("Time [days]")
plt.ylabel("ACF");

# %% [markdown]
# 220398107
#
# 220408525
#
# 220454507
#
# 220456530
#
# 220435980 -- maybe stitching is wrong?
#
# 220461732
#
# 220471204
#
# 220473309
#
# 220477676 -- very slow rotator!
#
# 260352227 -- example of which stitching is needed
#
# 260372062 -- slow rotator or something weird
#
# 260542381
#
# 260609205 -- possible planet
#
# 260636889
#
# 220408233
#
# 220471204
#
# Long rotators:
#
# 260372062 -- crazy. possibly long rotation period.
#
# 278684936 -- also crazy, possibly long rotation period.
#
# 278991333 -- clear long rotation period, around 15 days.
#
# 293972244 -- crazy. possibly long rotation period.
#
# 348839628 -- possible long period.
#
# 350334038 -- possible long period
#
# 350336553 -- 15 or 30 day period.
#
# 350478801_lc.png
